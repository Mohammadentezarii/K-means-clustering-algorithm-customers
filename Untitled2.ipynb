# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammadentezarii/PRODIGY_ML_02/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("/content/Mall_Customers.csv")
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
_df_8.plot(kind='scatter', x='Annual Income (k$)', y='Spending Score (1-100)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data.shape
# Out:
# (200, 5)

# %%
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data["A"] = data[["Annual Income (k$)"]]
data["B"] = data[["Spending Score (1-100)"]]

# %%
X = data[["A","B"]]
X.head()
# Out:
#     A   B
# 0  15  39
# 1  15  81
# 2  16   6
# 3  16  77
# 4  17  40

# %%
# @title A vs B
X.plot(kind='scatter', x='A', y='B', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
Kmean = KMeans(n_clusters = 5)
Kmean.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=5)

# %%
centers = Kmean.cluster_centers_
print(centers)
# Out:
# [[86.53846154 82.12820513]
#  [55.2962963  49.51851852]
#  [88.2        17.11428571]
#  [25.72727273 79.36363636]
#  [26.30434783 20.91304348]]

# %%
clusters = Kmean.fit_predict(X)
data["label"] = clusters
data.head(100)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#     CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)   A  \
# 0            1    Male   19                  15                      39  15
# 1            2    Male   21                  15                      81  15
# 2            3  Female   20                  16                       6  16
# 3            4  Female   23                  16                      77  16
# 4            5  Female   31                  17                      40  17
# ..         ...     ...  ...                 ...                     ...  ..
# 95          96    Male   24                  60                      52  60
# 96          97  Female   47                  60                      47  60
# ...

# %%
col = ['green', 'blue', 'black', 'yellow', 'orange']

for i in range(5):
  a = col[i]
  plt.scatter(data.A[data.label == i], data.B[data.label == i], c = a, label = 'cluser 1')
plt.scatter(centers[:, 0], centers[:, 1], marker = '*', s = 300, c = 'r', label = 'centroid')

# %%
X1 = X.loc[:,["A","B"]].values

# %%
wcss = []
for K in range(1, 11):
    Kmeans = KMeans(n_clusters=K, init="k-means++")
    Kmeans.fit(X1)
    wcss.append(Kmeans.inertia_)

plt.figure(figsize=(12, 6))
plt.grid()
plt.plot(range(1, 11), wcss, linewidth = 2, color='red', marker='8')
plt.xlabel('K Value')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...
